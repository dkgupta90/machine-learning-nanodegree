# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# Epoch 1/100
#  - 46s - loss: 1.6575 - acc: 0.3972 - val_loss: 1.3684 - val_acc: 0.5014
#
# Epoch 00001: val_loss improved from inf to 1.36837, saving model to aug_model.weights.best.hdf5
# Epoch 2/100
#  - 50s - loss: 1.3956 - acc: 0.4974 - val_loss: 1.2576 - val_acc: 0.5434
#
# Epoch 00002: val_loss improved from 1.36837 to 1.25762, saving model to aug_model.weights.best.hdf5
# Epoch 3/100
#  - 50s - loss: 1.2838 - acc: 0.5430 - val_loss: 1.1833 - val_acc: 0.5862
#
# Epoch 00003: val_loss improved from 1.25762 to 1.18327, saving model to aug_model.weights.best.hdf5
# Epoch 4/100
#  - 47s - loss: 1.2199 - acc: 0.5689 - val_loss: 1.1302 - val_acc: 0.6068
#
# Epoch 00004: val_loss improved from 1.18327 to 1.13018, saving model to aug_model.weights.best.hdf5
# Epoch 5/100
#  - 45s - loss: 1.1844 - acc: 0.5838 - val_loss: 1.0820 - val_acc: 0.6248
#
# Epoch 00005: val_loss improved from 1.13018 to 1.08199, saving model to aug_model.weights.best.hdf5
# Epoch 6/100
#  - 44s - loss: 1.1692 - acc: 0.5903 - val_loss: 1.0778 - val_acc: 0.6234
#
# Epoch 00006: val_loss improved from 1.08199 to 1.07780, saving model to aug_model.weights.best.hdf5
# Epoch 7/100
#  - 46s - loss: 1.1657 - acc: 0.5958 - val_loss: 1.0792 - val_acc: 0.6332
#
# Epoch 00007: val_loss did not improve from 1.07780
# Epoch 8/100
#  - 45s - loss: 1.1607 - acc: 0.6008 - val_loss: 1.0368 - val_acc: 0.6482
#
# Epoch 00008: val_loss improved from 1.07780 to 1.03681, saving model to aug_model.weights.best.hdf5
# Epoch 9/100
#  - 50s - loss: 1.1682 - acc: 0.5998 - val_loss: 1.0399 - val_acc: 0.6424
#
# Epoch 00009: val_loss did not improve from 1.03681
# Epoch 10/100
#  - 55s - loss: 1.1763 - acc: 0.5985 - val_loss: 1.0811 - val_acc: 0.6254
#
# Epoch 00010: val_loss did not improve from 1.03681
# Epoch 11/100
#  - 54s - loss: 1.1879 - acc: 0.5961 - val_loss: 1.1243 - val_acc: 0.6158
#
# Epoch 00011: val_loss did not improve from 1.03681
# Epoch 12/100
#  - 55s - loss: 1.1879 - acc: 0.5976 - val_loss: 1.2130 - val_acc: 0.6352
#
# Epoch 00012: val_loss did not improve from 1.03681
# Epoch 13/100
#  - 47s - loss: 1.2051 - acc: 0.5893 - val_loss: 1.0819 - val_acc: 0.6326
#
# Epoch 00013: val_loss did not improve from 1.03681
# Epoch 14/100
#  - 46s - loss: 1.2192 - acc: 0.5870 - val_loss: 1.0582 - val_acc: 0.6472
#
# Epoch 00014: val_loss did not improve from 1.03681
# Epoch 15/100
#  - 47s - loss: 1.2310 - acc: 0.5879 - val_loss: 1.1668 - val_acc: 0.6032
#
# Epoch 00015: val_loss did not improve from 1.03681
# Epoch 16/100
#  - 48s - loss: 1.2431 - acc: 0.5801 - val_loss: 1.1433 - val_acc: 0.6280
#
# Epoch 00016: val_loss did not improve from 1.03681
# Epoch 17/100
#  - 47s - loss: 1.2592 - acc: 0.5762 - val_loss: 1.1190 - val_acc: 0.6060
#
# Epoch 00017: val_loss did not improve from 1.03681
# Epoch 18/100
#  - 48s - loss: 1.2848 - acc: 0.5667 - val_loss: 1.1158 - val_acc: 0.6256
#
# Epoch 00018: val_loss did not improve from 1.03681
# Epoch 19/100
#  - 48s - loss: 1.2891 - acc: 0.5679 - val_loss: 1.0469 - val_acc: 0.6380
#
# Epoch 00019: val_loss did not improve from 1.03681
# Epoch 20/100
#  - 47s - loss: 1.3026 - acc: 0.5644 - val_loss: 1.1161 - val_acc: 0.6272
#
# Epoch 00020: val_loss did not improve from 1.03681
# Epoch 21/100
#  - 47s - loss: 1.3179 - acc: 0.5549 - val_loss: 1.1226 - val_acc: 0.6068
#
# Epoch 00021: val_loss did not improve from 1.03681
# Epoch 22/100
#  - 47s - loss: 1.3276 - acc: 0.5528 - val_loss: 1.1668 - val_acc: 0.5892
#
# Epoch 00022: val_loss did not improve from 1.03681
# Epoch 23/100
#  - 45s - loss: 1.3474 - acc: 0.5479 - val_loss: 1.1176 - val_acc: 0.6286
#
# Epoch 00023: val_loss did not improve from 1.03681
# Epoch 24/100
#  - 46s - loss: 1.3473 - acc: 0.5501 - val_loss: 1.1081 - val_acc: 0.6244
#
# Epoch 00024: val_loss did not improve from 1.03681
# Epoch 25/100
#  - 46s - loss: 1.3660 - acc: 0.5442 - val_loss: 1.1261 - val_acc: 0.6202
#
# Epoch 00025: val_loss did not improve from 1.03681
# Epoch 26/100
#  - 45s - loss: 1.3839 - acc: 0.5352 - val_loss: 1.2860 - val_acc: 0.5584
#
# Epoch 00026: val_loss did not improve from 1.03681
# Epoch 27/100
#  - 54s - loss: 1.4026 - acc: 0.5306 - val_loss: 1.2858 - val_acc: 0.5606
#
# Epoch 00027: val_loss did not improve from 1.03681
# Epoch 28/100
#  - 53s - loss: 1.4108 - acc: 0.5277 - val_loss: 1.3972 - val_acc: 0.5562
#
# Epoch 00028: val_loss did not improve from 1.03681
# Epoch 29/100
#  - 60s - loss: 1.4363 - acc: 0.5177 - val_loss: 1.1927 - val_acc: 0.5884
#
# Epoch 00029: val_loss did not improve from 1.03681
# Epoch 30/100
#  - 52s - loss: 1.4495 - acc: 0.5130 - val_loss: 1.2256 - val_acc: 0.5876
#
# Epoch 00030: val_loss did not improve from 1.03681
# Epoch 31/100
#  - 57s - loss: 1.4516 - acc: 0.5096 - val_loss: 1.4062 - val_acc: 0.5140
#
# Epoch 00031: val_loss did not improve from 1.03681
# Epoch 32/100
#  - 53s - loss: 1.4600 - acc: 0.5058 - val_loss: 1.1649 - val_acc: 0.5972
#
# Epoch 00032: val_loss did not improve from 1.03681
# Epoch 33/100
#  - 49s - loss: 1.4705 - acc: 0.5036 - val_loss: 1.2799 - val_acc: 0.5876
#
# Epoch 00033: val_loss did not improve from 1.03681
# Epoch 34/100
#  - 55s - loss: 1.4846 - acc: 0.4958 - val_loss: 1.3433 - val_acc: 0.5410
#
# Epoch 00034: val_loss did not improve from 1.03681
# Epoch 35/100
#  - 56s - loss: 1.5051 - acc: 0.4948 - val_loss: 1.2742 - val_acc: 0.5650
#
# Epoch 00035: val_loss did not improve from 1.03681
# Epoch 36/100
#  - 54s - loss: 1.5284 - acc: 0.4820 - val_loss: 1.3539 - val_acc: 0.5584
#
# Epoch 00036: val_loss did not improve from 1.03681
# Epoch 37/100
#  - 48s - loss: 1.5308 - acc: 0.4818 - val_loss: 1.3762 - val_acc: 0.5446
#
# Epoch 00037: val_loss did not improve from 1.03681
# Epoch 38/100
#  - 47s - loss: 1.5338 - acc: 0.4778 - val_loss: 1.2797 - val_acc: 0.5554
#
# Epoch 00038: val_loss did not improve from 1.03681
# Epoch 39/100
#  - 65s - loss: 1.5563 - acc: 0.4703 - val_loss: 1.4030 - val_acc: 0.5094
#
# Epoch 00039: val_loss did not improve from 1.03681
# Epoch 40/100
#  - 48s - loss: 1.5568 - acc: 0.4675 - val_loss: 1.3452 - val_acc: 0.5292
#
# Epoch 00040: val_loss did not improve from 1.03681
# Epoch 41/100
#  - 46s - loss: 1.5836 - acc: 0.4635 - val_loss: 1.4365 - val_acc: 0.5038
#
# Epoch 00041: val_loss did not improve from 1.03681
# Epoch 42/100
#  - 48s - loss: 1.5838 - acc: 0.4610 - val_loss: 1.4342 - val_acc: 0.5080
#
# Epoch 00042: val_loss did not improve from 1.03681
# Epoch 43/100
#  - 48s - loss: 1.5975 - acc: 0.4560 - val_loss: 1.4645 - val_acc: 0.4670
#
# Epoch 00043: val_loss did not improve from 1.03681
# Epoch 44/100
#  - 47s - loss: 1.5944 - acc: 0.4546 - val_loss: 2.0169 - val_acc: 0.4368
#
# Epoch 00044: val_loss did not improve from 1.03681
# Epoch 45/100
#  - 47s - loss: 1.6062 - acc: 0.4507 - val_loss: 1.3221 - val_acc: 0.5566
#
# Epoch 00045: val_loss did not improve from 1.03681
# Epoch 46/100
#  - 48s - loss: 1.6295 - acc: 0.4431 - val_loss: 1.3398 - val_acc: 0.5176
#
# Epoch 00046: val_loss did not improve from 1.03681
# Epoch 47/100
#  - 48s - loss: 1.6336 - acc: 0.4430 - val_loss: 1.4045 - val_acc: 0.5018
#
# Epoch 00047: val_loss did not improve from 1.03681
# Epoch 48/100
#  - 48s - loss: 1.6404 - acc: 0.4354 - val_loss: 1.3944 - val_acc: 0.5242
#
# Epoch 00048: val_loss did not improve from 1.03681
# Epoch 49/100
#  - 46s - loss: 1.6476 - acc: 0.4344 - val_loss: 1.3889 - val_acc: 0.5154
#
# Epoch 00049: val_loss did not improve from 1.03681
# Epoch 50/100
#  - 46s - loss: 1.6494 - acc: 0.4323 - val_loss: 1.5793 - val_acc: 0.4324
#
# Epoch 00050: val_loss did not improve from 1.03681
# Epoch 51/100
#  - 47s - loss: 1.6612 - acc: 0.4281 - val_loss: 1.5198 - val_acc: 0.4610
#
# Epoch 00051: val_loss did not improve from 1.03681
# Epoch 52/100
#  - 48s - loss: 1.6761 - acc: 0.4247 - val_loss: 1.4573 - val_acc: 0.4720
#
# Epoch 00052: val_loss did not improve from 1.03681
# Epoch 53/100
#  - 49s - loss: 1.6893 - acc: 0.4173 - val_loss: 1.7837 - val_acc: 0.4088
#
# Epoch 00053: val_loss did not improve from 1.03681
# Epoch 54/100
#  - 47s - loss: 1.7137 - acc: 0.4102 - val_loss: 1.5974 - val_acc: 0.4524
#
# Epoch 00054: val_loss did not improve from 1.03681
# Epoch 55/100
#  - 47s - loss: 1.7448 - acc: 0.3972 - val_loss: 1.5497 - val_acc: 0.4370
#
# Epoch 00055: val_loss did not improve from 1.03681
# Epoch 56/100
#  - 46s - loss: 1.7427 - acc: 0.3977 - val_loss: 1.6052 - val_acc: 0.4302
#
# Epoch 00056: val_loss did not improve from 1.03681
# Epoch 57/100
#  - 47s - loss: 1.7538 - acc: 0.3948 - val_loss: 1.5612 - val_acc: 0.4566
#
# Epoch 00057: val_loss did not improve from 1.03681
# Epoch 58/100
#  - 48s - loss: 1.7518 - acc: 0.3899 - val_loss: 1.5253 - val_acc: 0.4612
#
# Epoch 00058: val_loss did not improve from 1.03681
# Epoch 59/100
#  - 46s - loss: 1.7434 - acc: 0.3931 - val_loss: 1.5074 - val_acc: 0.4642
#
# Epoch 00059: val_loss did not improve from 1.03681
# Epoch 60/100
#  - 49s - loss: 1.7457 - acc: 0.3914 - val_loss: 1.5934 - val_acc: 0.4508
#
# Epoch 00060: val_loss did not improve from 1.03681
# Epoch 61/100
#  - 48s - loss: 1.7516 - acc: 0.3928 - val_loss: 1.5089 - val_acc: 0.4612
#
# Epoch 00061: val_loss did not improve from 1.03681
# Epoch 62/100
#  - 46s - loss: 1.7618 - acc: 0.3844 - val_loss: 1.7281 - val_acc: 0.3902
#
# Epoch 00062: val_loss did not improve from 1.03681
# Epoch 63/100
#  - 46s - loss: 1.7767 - acc: 0.3821 - val_loss: 1.6067 - val_acc: 0.4350
#
# Epoch 00063: val_loss did not improve from 1.03681
# Epoch 64/100
#  - 46s - loss: 1.7849 - acc: 0.3775 - val_loss: 1.5498 - val_acc: 0.4576
#
# Epoch 00064: val_loss did not improve from 1.03681
# Epoch 65/100
#  - 46s - loss: 1.8010 - acc: 0.3730 - val_loss: 1.5264 - val_acc: 0.4556
#
# Epoch 00065: val_loss did not improve from 1.03681
# Epoch 66/100
#  - 47s - loss: 1.7844 - acc: 0.3772 - val_loss: 2.8416 - val_acc: 0.3610
#
# Epoch 00066: val_loss did not improve from 1.03681
# Epoch 67/100
#  - 47s - loss: 1.8151 - acc: 0.3676 - val_loss: 1.6216 - val_acc: 0.4148
#
# Epoch 00067: val_loss did not improve from 1.03681
# Epoch 68/100
#  - 46s - loss: 1.8128 - acc: 0.3657 - val_loss: 1.6356 - val_acc: 0.4038
#
# Epoch 00068: val_loss did not improve from 1.03681
# Epoch 69/100
#  - 47s - loss: 1.8316 - acc: 0.3627 - val_loss: 1.6332 - val_acc: 0.4184
#
# Epoch 00069: val_loss did not improve from 1.03681
# Epoch 70/100
#  - 47s - loss: 1.8432 - acc: 0.3524 - val_loss: 1.7519 - val_acc: 0.3420
#
# Epoch 00070: val_loss did not improve from 1.03681
# Epoch 71/100
#  - 47s - loss: 1.8305 - acc: 0.3575 - val_loss: 1.6487 - val_acc: 0.3926
#
# Epoch 00071: val_loss did not improve from 1.03681
# Epoch 72/100
#  - 48s - loss: 1.8322 - acc: 0.3572 - val_loss: 1.8798 - val_acc: 0.3476
#
# Epoch 00072: val_loss did not improve from 1.03681
# Epoch 73/100
#  - 47s - loss: 1.8433 - acc: 0.3483 - val_loss: 1.6945 - val_acc: 0.4144
#
# Epoch 00073: val_loss did not improve from 1.03681
# Epoch 74/100
#  - 46s - loss: 1.8447 - acc: 0.3494 - val_loss: 1.7184 - val_acc: 0.4260
#
# Epoch 00074: val_loss did not improve from 1.03681
# Epoch 75/100
#  - 54s - loss: 1.8309 - acc: 0.3525 - val_loss: 1.6447 - val_acc: 0.4162
#
# Epoch 00075: val_loss did not improve from 1.03681
# Epoch 76/100
#  - 46s - loss: 1.8469 - acc: 0.3519 - val_loss: 1.7667 - val_acc: 0.3650
#
# Epoch 00076: val_loss did not improve from 1.03681
# Epoch 77/100
#  - 46s - loss: 1.8409 - acc: 0.3508 - val_loss: 1.7023 - val_acc: 0.3994
#
# Epoch 00077: val_loss did not improve from 1.03681
# Epoch 78/100
#  - 47s - loss: 1.8528 - acc: 0.3421 - val_loss: 1.8088 - val_acc: 0.3350
#
# Epoch 00078: val_loss did not improve from 1.03681
# Epoch 79/100
#  - 47s - loss: 1.8690 - acc: 0.3380 - val_loss: 1.6300 - val_acc: 0.4036
#
# Epoch 00079: val_loss did not improve from 1.03681
# Epoch 80/100
#  - 47s - loss: 1.8607 - acc: 0.3419 - val_loss: 1.6728 - val_acc: 0.3734
#
# Epoch 00080: val_loss did not improve from 1.03681
# Epoch 81/100
#  - 54s - loss: 1.8583 - acc: 0.3376 - val_loss: 1.7089 - val_acc: 0.3950
#
# Epoch 00081: val_loss did not improve from 1.03681
# Epoch 82/100
#  - 53s - loss: 1.8658 - acc: 0.3424 - val_loss: 1.7070 - val_acc: 0.3814
#
# Epoch 00082: val_loss did not improve from 1.03681
# Epoch 83/100
#  - 51s - loss: 1.8657 - acc: 0.3404 - val_loss: 1.6904 - val_acc: 0.4084
#
# Epoch 00083: val_loss did not improve from 1.03681
# Epoch 84/100
#  - 48s - loss: 1.8733 - acc: 0.3344 - val_loss: 1.8252 - val_acc: 0.3462
#
# Epoch 00084: val_loss did not improve from 1.03681
# Epoch 85/100
#  - 48s - loss: 1.8548 - acc: 0.3377 - val_loss: 1.7425 - val_acc: 0.3572
#
# Epoch 00085: val_loss did not improve from 1.03681
# Epoch 86/100
#  - 49s - loss: 1.8590 - acc: 0.3337 - val_loss: 1.6920 - val_acc: 0.3466
#
# Epoch 00086: val_loss did not improve from 1.03681
# Epoch 87/100
#  - 49s - loss: 1.8593 - acc: 0.3345 - val_loss: 1.7045 - val_acc: 0.3944
#
# Epoch 00087: val_loss did not improve from 1.03681
# Epoch 88/100
#  - 47s - loss: 1.8685 - acc: 0.3371 - val_loss: 1.6715 - val_acc: 0.4008
#
# Epoch 00088: val_loss did not improve from 1.03681
# Epoch 89/100
#  - 46s - loss: 1.8582 - acc: 0.3324 - val_loss: 1.6338 - val_acc: 0.4064
#
# Epoch 00089: val_loss did not improve from 1.03681
# Epoch 90/100
#  - 48s - loss: 1.8555 - acc: 0.3371 - val_loss: 1.6737 - val_acc: 0.4164
#
# Epoch 00090: val_loss did not improve from 1.03681
# Epoch 91/100
#  - 49s - loss: 1.8602 - acc: 0.3388 - val_loss: 1.5969 - val_acc: 0.4218
#
# Epoch 00091: val_loss did not improve from 1.03681
# Epoch 92/100
#  - 49s - loss: 1.8782 - acc: 0.3297 - val_loss: 1.7285 - val_acc: 0.3800
#
# Epoch 00092: val_loss did not improve from 1.03681
# Epoch 93/100
#  - 50s - loss: 1.8743 - acc: 0.3236 - val_loss: 1.7041 - val_acc: 0.3990
#
# Epoch 00093: val_loss did not improve from 1.03681
# Epoch 94/100
#  - 50s - loss: 1.8773 - acc: 0.3253 - val_loss: 1.8447 - val_acc: 0.3540
#
# Epoch 00094: val_loss did not improve from 1.03681
# Epoch 95/100
#  - 50s - loss: 1.8731 - acc: 0.3205 - val_loss: 1.6637 - val_acc: 0.4008
#
# Epoch 00095: val_loss did not improve from 1.03681
# Epoch 96/100
#  - 49s - loss: 1.8903 - acc: 0.3209 - val_loss: 1.7627 - val_acc: 0.3502
#
# Epoch 00096: val_loss did not improve from 1.03681
# Epoch 97/100
#  - 49s - loss: 1.8877 - acc: 0.3136 - val_loss: 1.7079 - val_acc: 0.3694
#
# Epoch 00097: val_loss did not improve from 1.03681
# Epoch 98/100
#  - 49s - loss: 1.8999 - acc: 0.3159 - val_loss: 1.7163 - val_acc: 0.3842
#
# Epoch 00098: val_loss did not improve from 1.03681
# Epoch 99/100
#  - 49s - loss: 1.8965 - acc: 0.3056 - val_loss: 1.9592 - val_acc: 0.3542
#
# Epoch 00099: val_loss did not improve from 1.03681
# Epoch 100/100
#  - 49s - loss: 1.8943 - acc: 0.3089 - val_loss: 1.7051 - val_acc: 0.3732
#
# Epoch 00100: val_loss did not improve from 1.03681

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6825
